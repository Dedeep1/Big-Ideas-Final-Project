# %% [markdown]
# # Parks

# %% [markdown]
# ## <u>Why parks as a metric:</u>

# %% [markdown]
# We chose parks as a metric to display the quality of life in neighborhoods within the city of Pittsburgh. Someone when choosing a neighborhood to live in would massively consider their surroundings with parks being a heavy factor. Parks improve quality of life and overall add positivity when around neighborhoods especially in cities. A neighborhood may be around a lot of parks, but the parks' quality matter too. The perfect balance would be more quality than quantity.

# %%
import pandas as pd
import geopandas
# %matplotlib inline

# %%
link = "https://data.wprdc.org/datastore/dump/fa329e3d-89ff-4708-8ddf-81bfedcad11d"
df = pd.read_csv(link)
df
# Out:
#      _id          id                     name        type  \
# 0      1  2111959181           Able Long Park        Park
# 1      2  1109513049  Albert Turk Graham Park        Park
# 2      3  1544096765               Alcoa Park        Park
# 3      4  1212681573        Allegheny Commons        Park
# 4      5   954863286   Allegheny Landing Park        Park
# ..   ...         ...                      ...         ...
# 204  205  1460363095           Woods Run Park        Park
# 205  206   930068146         Young Field Park        Park
# 206  207  1127012019              Zulema Park        Park
# 207  208  1719897212       Liberty Green Park        Park
# 208  241  1305573349         Esser Plaza Park  Open Space
#
#     maintenance_responsibility  \
# 0             Parks - Southern
# 1             Parks - Schenley
# 2             Parks - Northern
# 3             Parks - Northern
# 4             Parks - Northern
# ..                         ...
# 204           Parks - Northern
# ...

# %% [markdown]
# # Below lies a map that gives the density of parks based on the area

# %%
import pandas as pd
import matplotlib.pyplot as plt

link = "https://data.wprdc.org/datastore/dump/fa329e3d-89ff-4708-8ddf-81bfedcad11d"
df = pd.read_csv(link)


selected_columns = ['name', 'neighborhood', 'latitude', 'longitude', 'type', 'maintenance_responsibility']
df_selected = df[selected_columns]


df_selected = df_selected.dropna(subset=['latitude', 'longitude'])


neighborhood_counts = df_selected['neighborhood'].value_counts()


plt.figure(figsize=(20, 8))
plt.bar(neighborhood_counts.index, neighborhood_counts.values, color='blue')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Plots')
plt.title('Density of Plots for Each Neighborhood')
plt.xticks(rotation=90)  
plt.grid(True)
plt.show()
